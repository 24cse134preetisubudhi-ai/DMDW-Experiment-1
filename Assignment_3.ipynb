# %% [markdown]
# <a href="https://colab.research.google.com/github/24cse134preetisubudhi-ai/DMDW-Experiment-1/blob/main/Assignment_3.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd

# %%
df=pd.read_csv('/Book2.csv')

# %%
df
# Out:
#    C:\Users\student\Desktop\24CSE134 Name  marks
# 0                                  1    a     45
# 1                                  2    b     67
# 2                                  3    c     78
# 3                                  4    d     98
# 4                                  5    e     56
# 5                                  6    f     47
# 6                                  7    g     89
# 7                                  8    h     95
# 8                                  9    i     34
# 9                                 10    j     78

# %%
df.head()
# Out:
#    C:\Users\student\Desktop\24CSE134 Name  marks
# 0                                  1    a     45
# 1                                  2    b     67
# 2                                  3    c     78
# 3                                  4    d     98
# 4                                  5    e     56

# %%
df.tail()
# Out:
#    C:\Users\student\Desktop\24CSE134 Name  marks
# 5                                  6    f     47
# 6                                  7    g     89
# 7                                  8    h     95
# 8                                  9    i     34
# 9                                 10    j     78

# %%
df.head(7)
# Out:
#    C:\Users\student\Desktop\24CSE134 Name  marks
# 0                                  1    a     45
# 1                                  2    b     67
# 2                                  3    c     78
# 3                                  4    d     98
# 4                                  5    e     56
# 5                                  6    f     47
# 6                                  7    g     89

# %%
df.tail(6)
# Out:
#    C:\Users\student\Desktop\24CSE134 Name  marks
# 4                                  5    e     56
# 5                                  6    f     47
# 6                                  7    g     89
# 7                                  8    h     95
# 8                                  9    i     34
# 9                                 10    j     78

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10 entries, 0 to 9
# Data columns (total 3 columns):
#  #   Column                             Non-Null Count  Dtype
# ---  ------                             --------------  -----
#  0   C:\Users\student\Desktop\24CSE134  10 non-null     int64
#  1   Name                               10 non-null     object
#  2   marks                              10 non-null     int64
# dtypes: int64(2), object(1)
# memory usage: 372.0+ bytes

# %%
df.describe()
# Out:
#        C:\Users\student\Desktop\24CSE134      marks
# count                           10.00000  10.000000
# mean                             5.50000  68.700000
# std                              3.02765  22.450192
# min                              1.00000  34.000000
# 25%                              3.25000  49.250000
# 50%                              5.50000  72.500000
# 75%                              7.75000  86.250000
# max                             10.00000  98.000000

# %%
df.shape
# Out:
# (10, 3)

# %%
df.columns
# Out:
# Index(['C:\Users\student\Desktop\24CSE134', 'Name', 'marks'], dtype='object')

# %%
df.dtypes
# Out:
# C:\Users\student\Desktop\24CSE134     int64
# Name                                 object
# marks                                 int64
# dtype: object

# %%
df.isnull()
# Out:
#    C:\Users\student\Desktop\24CSE134   Name  marks
# 0                              False  False  False
# 1                              False  False  False
# 2                              False  False  False
# 3                              False  False  False
# 4                              False  False  False
# 5                              False  False  False
# 6                              False  False  False
# 7                              False  False  False
# 8                              False  False  False
# 9                              False  False  False

# %%
df.iloc[0]
# Out:
# C:\Users\student\Desktop\24CSE134     1
# Name                                  a
# marks                                45
# Name: 0, dtype: object

# %%
df.loc[0]
# Out:
# C:\Users\student\Desktop\24CSE134     1
# Name                                  a
# marks                                45
# Name: 0, dtype: object
